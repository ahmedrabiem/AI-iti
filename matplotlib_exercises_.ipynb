# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedrabiem/AI-iti/blob/main/matplotlib_exercises_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib Practice
#
# This notebook offers a set of exercises to different tasks with Matplotlib.
#
# It should be noted there may be more than one different way to answer a question or complete an exercise.
#
# Different tasks will be detailed by comments or text.

# %%
# Import the pyplot module from matplotlib as plt and make sure
# plots appear in the notebook using '%matplotlib inline'
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create a simple plot using plt.plot()
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x, y)
plt.show()

# %%
# Plot a single Python list
data = [3, 7, 1, 5, 9]

plt.plot(data)
plt.show()

# %%
# Create two lists, one called X, one called y, each with 5 numbers in them
X = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# %%
# Plot X & y (the lists you've created)
plt.plot(X, y)
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Plot of X vs Y")
plt.show()

# %% [markdown]
# *There*'s another way to create plots with Matplotlib, it's known as the object-orientated (OO) method. Let's try it.

# %%
# Create a plot using plt.subplots()
fig, ax = plt.subplots()
x = [1, 2, 3, 4, 5]
y = [n**2 for n in x]
ax.plot(x, y)

ax.set_title("Plot using plt.subplots()")
ax.set_xlabel("X values")
ax.set_ylabel("Y values")

plt.show()

# %%
# Create a plot using plt.subplots() and then add X & y on the axes

import matplotlib.pyplot as plt

X = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

fig, ax = plt.subplots()

ax.plot(X, y)

ax.set_title("X vs y using OO method")
ax.set_xlabel("X values")
ax.set_ylabel("y values")

plt.show()

# %% [markdown]
# Now let's try a small matplotlib workflow.

# %%
# Import and get matplotlib ready


# Prepare data (create two lists of 5 numbers, X & y)


# Setup figure and axes using plt.subplots()


# Add data (X, y) to axes


# Customize plot by adding a title, xlabel and ylabel


# Save the plot to file using fig.savefig()

import matplotlib.pyplot as plt

X = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

fig, ax = plt.subplots()

ax.plot(X, y)

ax.set_title("Simple Matplotlib Workflow")
ax.set_xlabel("X values")
ax.set_ylabel("y values")

fig.savefig("my_first_plot.png")

plt.show()

# %% [markdown]
# Okay, this is a simple line plot, how about something a little different?
#
# To help us, we'll import NumPy.

# %%
# Import NumPy as np
import numpy as np

# %%
# Create an array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable X
X = np.linspace(0, 100, 100)

X[:10]
# Out:
# array([0.        , 1.01010101, 2.02020202, 3.03030303, 4.04040404,
#        5.05050505, 6.06060606, 7.07070707, 8.08080808, 9.09090909])

# %%
# Create a plot using plt.subplots() and plot X versus X^2 (X squared)
fig, ax = plt.subplots()

ax.plot(X, X**2)

ax.set_title("Plot of X vs X^2")
ax.set_xlabel("X values")
ax.set_ylabel("X squared")

plt.show()

# %% [markdown]
# # We'll start with scatter plots.

# %%
# Create a scatter plot of X versus the exponential of X (np.exp(X))
fig, ax = plt.subplots()

ax.scatter(X, np.exp(X))

ax.set_title("Scatter Plot of X vs exp(X)")
ax.set_xlabel("X values")
ax.set_ylabel("exp(X) values")

plt.show()

# %%
# Create a scatter plot of X versus np.sin(X)
fig, ax = plt.subplots()

ax.scatter(X, np.sin(X))

ax.set_title("Scatter Plot of X vs sin(X)")
ax.set_xlabel("X values")
ax.set_ylabel("sin(X) values")

plt.show()

# %% [markdown]
# How about we try another type of plot? This time let's look at a bar plot. First we'll make some data.

# %%
# Create a Python dictionary of 3 of your favourite foods with
# The keys of the dictionary should be the food name and the values their price
favourite_foods = {
    "Pizza": 120,
    "Burger": 80,
    "Pasta": 90
}

favourite_foods
# Out:
# {'Pizza': 120, 'Burger': 80, 'Pasta': 90}

# %%
# Create a bar graph where the x-axis is the keys of the dictionary
# and the y-axis is the values of the dictionary


# Add a title, xlabel and ylabel to the plot
import matplotlib.pyplot as plt

favourite_foods = {
    "Pizza": 120,
    "Burger": 80,
    "Pasta": 90
}

foods = list(favourite_foods.keys())
prices = list(favourite_foods.values())

fig, ax = plt.subplots()
ax.bar(foods, prices)

ax.set_title("Favourite Foods and Their Prices")
ax.set_xlabel("Food")
ax.set_ylabel("Price (EGP)")

plt.show()

# %%
# Make the same plot as above, except this time make the bars go horizontal

favourite_foods = {
    "Pizza": 120,
    "Burger": 80,
    "Pasta": 90
}

foods = list(favourite_foods.keys())
prices = list(favourite_foods.values())

fig, ax = plt.subplots()
ax.barh(foods, prices)

ax.set_title("Favourite Foods and Their Prices (Horizontal)")
ax.set_xlabel("Price (EGP)")
ax.set_ylabel("Food")

plt.show()

# %% [markdown]
# All this food plotting is making me hungry. But we've got a couple of plots to go.
#
# Let's see a histogram.

# %%
# Create a random NumPy array of 1000 normally distributed numbers using NumPy and save it to X


# Create a histogram plot of X
X = np.random.randn(1000)

fig, ax = plt.subplots()
ax.hist(X, bins=30, edgecolor="black")

ax.set_title("Histogram of Normally Distributed Data")
ax.set_xlabel("Value")
ax.set_ylabel("Frequency")

plt.show()

# %%
# Create a NumPy array of 1000 random numbers and save it to X


# Create a histogram plot of X
X = np.random.rand(1000)
fig, ax = plt.subplots()
ax.hist(X, bins=20, edgecolor="black")

ax.set_title("Histogram of Random Numbers")
ax.set_xlabel("Value")
ax.set_ylabel("Frequency")

plt.show()

# %% [markdown]
# Notice how the distributions (spread of data) are different. Why do they differ?
#
# What else can you find out about the normal distribution?
#
# Can you think of any other kinds of data which may be normally distributed?
#
# These questions aren't directly related to plotting or Matplotlib but they're helpful to think of.
#
# Now let's try make some subplots. A subplot is another name for a figure with multiple plots on it.

# %%
# Create an empty subplot with 2 rows and 2 columns (4 subplots total)
fig, ax = plt.subplots(nrows=2, ncols=2)

plt.show()

# %% [markdown]
# Notice how the subplot has multiple figures. Now let's add data to each axes.

# %%
# Create the same plot as above with 2 rows and 2 columns and figsize of (10, 5)


# Plot X versus X/2 on the top left axes


# Plot a scatter plot of 10 random numbers on each axis on the top right subplot


# Plot a bar graph of the favourite food keys and values on the bottom left subplot


# Plot a histogram of 1000 random normally distributed numbers on the bottom right subplot
X = np.linspace(0, 10, 100)
foods = {"Pizza": 50, "Burger": 30, "Sushi": 70}

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

ax[0, 0].plot(X, X/2)
ax[0, 0].set_title("Line Plot: X vs X/2")

rand_x = np.random.rand(10)
rand_y = np.random.rand(10)
ax[0, 1].scatter(rand_x, rand_y, color="green")
ax[0, 1].set_title("Random Scatter")

ax[1, 0].bar(foods.keys(), foods.values(), color="orange")
ax[1, 0].set_title("Favourite Foods")

rand_norm = np.random.randn(1000)
ax[1, 1].hist(rand_norm, bins=30, color="purple")
ax[1, 1].set_title("Normal Distribution Histogram")

plt.tight_layout()
plt.show()

# %% [markdown]
# Woah. There's a lot going on there.
#
# Now we've seen how to plot with Matplotlib and data directly. Let's practice using Matplotlib to plot with pandas.
#
# First we'll need to import pandas and create a DataFrame work with.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import pandas as pd
import pandas as pd

# %%
# Import the '../data/car-sales.csv' into a DataFame called car_sales and view
car_sales = pd.read_csv("/content/drive/MyDrive/data/car-sales - car-sales.csv")

car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
print(car_sales.columns)
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# Try to plot the 'Price' column using the plot() function
car_sales["Price"] = car_sales["Price"].replace('[\$,]', '', regex=True).astype(float)

car_sales["Price"].plot()

plt.show()

# %% [markdown]
# Why doesn't it work?
#
# Hint: It's not numeric data.
#
# In the process of turning it to numeric data, let's create another column which adds the total amount of sales and another one which shows what date the car was sold.
#
# Hint: To add a column up cumulatively, look up the cumsum() function. And to create a column of dates, look up the date_range() function.

# %%
# Remove the symbols, the final two numbers from the 'Price' column and convert it to numbers
import pandas as pd
import matplotlib.pyplot as plt

car_sales = pd.read_csv("/content/drive/MyDrive/data/car-sales - car-sales.csv")

car_sales["Price"] = car_sales["Price"].str.replace('[\$,]', '', regex=True)
car_sales["Price"] = car_sales["Price"].str.replace('.00', '', regex=False).astype(int)

car_sales["Total Sales"] = car_sales["Price"].cumsum()

car_sales["Sale Date"] = pd.date_range(start="2023-01-01", periods=len(car_sales), freq="D")

print(car_sales)

car_sales["Price"].plot()
plt.show()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   4000         4000 2023-01-01
# 1   Honda    Red          87899      4   5000         9000 2023-01-02
# 2  Toyota   Blue          32549      3   7000        16000 2023-01-03
# 3     BMW  Black          11179      5  22000        38000 2023-01-04
# 4  Nissan  White         213095      4   3500        41500 2023-01-05
# 5  Toyota  Green          99213      4   4500        46000 2023-01-06
# 6   Honda   Blue          45698      4   7500        53500 2023-01-07
# 7   Honda   Blue          54738      4   7000        60500 2023-01-08
# 8  Toyota  White          60000      4   6250        66750 2023-01-09
# 9  Nissan  White          31600      4   9700        76450 2023-01-10

# %%
# Add a column called 'Total Sales' to car_sales which cumulatively adds the 'Price' column (cumsum())


# Add a column called 'Sale Date' which lists a series of successive dates starting from today (your today)

# View the car_sales DataFrame
import pandas as pd
import matplotlib.pyplot as plt

car_sales = pd.read_csv("/content/drive/MyDrive/data/car-sales - car-sales.csv")


car_sales["Price"] = car_sales["Price"].str.replace('[\$,]', '', regex=True)
car_sales["Price"] = car_sales["Price"].str.replace('.00', '', regex=False).astype(int)

# إضافة عمود Total Sales (مجموع تراكمي للأسعار)
car_sales["Total Sales"] = car_sales["Price"].cumsum()

# إضافة عمود Sale Date (تواريخ متتالية بداية من تاريخ اليوم)
car_sales["Sale Date"] = pd.date_range(start=pd.Timestamp.today().normalize(),
                                       periods=len(car_sales),
                                       freq="D")

# عرض البيانات بعد التعديلات
print(car_sales)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   4000         4000 2025-08-19
# 1   Honda    Red          87899      4   5000         9000 2025-08-20
# 2  Toyota   Blue          32549      3   7000        16000 2025-08-21
# 3     BMW  Black          11179      5  22000        38000 2025-08-22
# 4  Nissan  White         213095      4   3500        41500 2025-08-23
# 5  Toyota  Green          99213      4   4500        46000 2025-08-24
# 6   Honda   Blue          45698      4   7500        53500 2025-08-25
# 7   Honda   Blue          54738      4   7000        60500 2025-08-26
# 8  Toyota  White          60000      4   6250        66750 2025-08-27
# 9  Nissan  White          31600      4   9700        76450 2025-08-28

# %% [markdown]
# Now we've got a numeric column (`Total Sales`) and a dates column (`Sale Date`), let's visualize them.

# %%
# Use the plot() function to plot the 'Sale Date' column versus the 'Total Sales' column

car_sales.plot(x="Sale Date", y="Total Sales", kind="line", marker="o")

plt.title("Car Sales Over Time")
plt.xlabel("Sale Date")
plt.ylabel("Total Sales ($)")
plt.grid(True)
plt.show()

# %%
# Convert the 'Price' column to the integers


# Create a scatter plot of the 'Odometer (KM)' and 'Price' column using the plot() function
car_sales["Price"] = car_sales["Price"].replace('[\$,]', '', regex=True).astype(int)

car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")

plt.title("Price vs Odometer (KM)")
plt.xlabel("Odometer (KM)")
plt.ylabel("Price ($)")
plt.show()

# %%
# Create a NumPy array of random numbers of size (10, 4) and save it to X


# Turn the NumPy array X into a DataFrame with columns called ['a', 'b', 'c', 'd']


# Create a bar graph of the DataFrame
X = np.random.rand(10, 4)

# 2. تحويل المصفوفة إلى DataFrame مع تسمية الأعمدة
df = pd.DataFrame(X, columns=['a', 'b', 'c', 'd'])

# 3. رسم Bar Graph
df.plot(kind="bar", figsize=(10,6))

plt.title("Bar Graph of Random Data")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %%
# Create a bar graph of the 'Make' and 'Odometer (KM)' columns in the car_sales DataFrame
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar", figsize=(10,6))

plt.title("Car Odometer Readings by Make")
plt.xlabel("Car Make")
plt.ylabel("Odometer (KM)")
plt.show()

# %%
# Create a histogram of the 'Odometer (KM)' column
car_sales["Odometer (KM)"].plot(kind="hist", bins=20, figsize=(8,5))

plt.title("Distribution of Odometer (KM)")
plt.xlabel("Odometer (KM)")
plt.ylabel("Frequency")
plt.show()

# %%
# Create a histogram of the 'Price' column with 20 bins
car_sales["Price"].plot(kind="hist", bins=20, figsize=(8,5))

plt.title("Distribution of Car Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()
